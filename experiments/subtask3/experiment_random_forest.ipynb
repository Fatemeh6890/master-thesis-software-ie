# %% [markdown]
# # Experiment: Use classic machine learning approach (Random Forest) for relation classification

# %%
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
pd.set_option("max_colWidth", 300)
# Out:
# C:\Users\fschr\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Read the datasets

# %%
train_set = pd.read_json("../../data/subtask3/train_prepro.json")
valid_set = pd.read_json("../../data/subtask3/valid_prepro.json")
test_set = pd.read_json("../../data/subtask3/test_prepro.json")

# %%
labels = [
    'Version_of',
    'Developer_of',
    'Citation_of',
    'URL_of',
    'PlugIn_of',
    'Specification_of',
    'Release_of',
    'Extension_of',
    'License_of',    
    'Abbreviation_of',
    'AlternativeName_of',
]

# %% [markdown]
# # Feature Selection and Preparation

# %%
features_text = [
      # 'context',
       'sentence',
       'subject_text',
       'object_text'
]
features_cat = [
       #'target_label_binary',
       'subject_label',
       'subject_intention',
       'object_label',
       'object_intention',
       # Maybe other labels? 'entities',        
]
features_int = [
    "subject_begin",
    "subject_end",
    "object_begin",
    "object_end",
    'subject_object_distance',
    'max_distance_train',
    'left_to_right', # binary
    'unprobable_relation_direction', # binary
    'n_alternative_candidates_by_subject',
    'n_alternative_candidates_by_subject_filtered',
    'rank_by_candidate_distance', 'rank_by_candidate_distance_filtered'
]

# %%
## Not giving better results (kept, maybe helpfull later)
def text_between(rel):
    token = rel["sentence"].split()
    if rel.subject_end < rel.object_begin:
        return " ".join(token[rel.subject_end + 1: rel.object_begin])
    if rel.object_end < rel.subject_begin:
        return " ".join(token[rel.object_end + 1 : rel.subject_begin])
train_set["text_between_ents"] = train_set[["sentence", "subject_begin", "subject_end", "object_begin", "object_end"]].apply(text_between, axis=1)

# %% [markdown]
# ### Build tokenizer

# %%
punctuation = "\.\(\)\[\]\,\:\;\"\'\/_/+"
token_pattern = f'(?u)(?:\\b\\w+\\b|[{punctuation}])'
vect = TfidfVectorizer(min_df=10, ngram_range=(1,2), token_pattern=token_pattern)
vect_subj = TfidfVectorizer(min_df=1, analyzer="word", ngram_range=(1,1), token_pattern=token_pattern, lowercase=False)
vect_obj = TfidfVectorizer(min_df=1, analyzer="word", ngram_range=(1,1), token_pattern=token_pattern, lowercase=False)
hih = vect.fit_transform(train_set.text_between_ents)
hah = vect_subj.fit_transform(train_set.subject_text.unique())
huh = vect_obj.fit_transform(train_set.object_text.unique())
hah.shape, hih.shape, huh.shape
# Out:
# ((1150, 1183), (4450, 1275), (636, 808))

# %%
enc = OneHotEncoder(sparse_output=False)
enc.fit(train_set[features_cat]);

# %%
def get_features(dataset):
    """ function to transform features for classifier
    """
    dataset["rank_by_candidate_distance_filtered"] = dataset.rank_by_candidate_distance_filtered.apply(lambda x: x if x != -1 else 100)#.value_counts()
    X = dataset[features_int].astype(int)
    X_cat = pd.DataFrame(enc.transform(dataset[features_cat]), columns = enc.get_feature_names_out(), index=X.index)
    X = X.join(X_cat)
    ## Text features
    dataset["text_between_ents"] = train_set[["sentence", "subject_begin", "subject_end", "object_begin", "object_end"]].apply(text_between, axis=1)
    X_text_between = vect.transform(dataset["text_between_ents"])
    X_text_between = pd.DataFrame(X_text_between.toarray(), columns=[f"text_between_{w}" for w in vect.get_feature_names_out()])
    #X = X.join(X_text_between)
    X_text_subject = vect_subj.transform(dataset["subject_text"])
    X_text_subject = pd.DataFrame(X_text_subject.toarray(), columns=[f"text_subject_{w}" for w in vect_subj.get_feature_names_out()])
    X = X.join(X_text_subject)
    X_text_object = vect_obj.transform(dataset["object_text"])
    X_text_object = pd.DataFrame(X_text_object.toarray(), columns=[f"text_object_{w}" for w in vect_obj.get_feature_names_out()])
    X = X.join(X_text_object)
    return X.copy()

# %% [markdown]
# ### Correction method to force for specific labels: one prediction per subject
#  * (All but PlugIn_of, Specification_of, Extension_of)

# %%
labels_with_one_relation = {
    'Version_of',
    'Developer_of',
    'Citation_of',
    'URL_of',
     #'PlugIn_of',
     #'Specification_of',
     'Release_of',
     #'Extension_of',
     'License_of',
     'Abbreviation_of',
     'AlternativeName_of'}
def force_one(pred):
    if pred.iloc[0].target_label_binary in labels_with_one_relation:
        pred = pred.sort_values("proba", ascending=False)
        pred["prediction_force_one"] = 0
        index_first = pred.index[0]
        pred.loc[index_first, "prediction_force_one"] = 1
    else:
        pred["prediction_force_one"] = (pred.proba >= 0.5).astype(int)
    return pred.set_index("object_begin").prediction_force_one

def force_one_label(dataset, prediction, prediction_proba):
    data = dataset.copy()
    data["prediction"] = prediction
    data["proba"] = prediction_proba[:,1]
    subject_key = ["sentence_id", "subject_begin"]
    pred_force_one = data.groupby(subject_key)[["target_label_binary", "object_begin", "proba"]].apply(force_one)
    data = data.set_index(subject_key + ["object_begin"]).join(pred_force_one).reset_index()
    prediction_label_force_one = data[["target_label_binary", "prediction_force_one"]]\
        .apply(lambda x: x.target_label_binary if x.prediction_force_one == 1 else 'nil', axis=1)
    return data.prediction_force_one, prediction_label_force_one

# %% [markdown]
# ## Prepare data

# %%
X_train = get_features(train_set)
y_train = train_set.label_binary

X_valid = get_features(valid_set)
y_valid_label_pred = valid_set.target_label_binary.to_numpy()
y_valid = valid_set.label_binary
y_valid_label = valid_set.relation.to_numpy()

X_test = get_features(test_set)
y_test_label_pred = test_set.target_label_binary.to_numpy()
y_test = test_set.label_binary
y_test_label = test_set.relation.to_numpy()

len(y_valid_label), len(y_test_label)
# Out:
# (1446, 960)

# %% [markdown]
# # Train Random Forest (use 5 runs)

# %%
# %%time
model = RandomForestClassifier(
    #n_estimators=1000,
    #max_depth=10,
    #min_samples_split=10, #2
    #min_samples_leaf=10, #1 
)
eval_results = []
for run in range(5):
    model.fit(X_train, y_train)
    y_valid_pred = model.predict(X_valid)
    y_valid_pred_label = ["nil" if p == 0 else y_valid_label_pred[idx]  for idx, p in enumerate(y_valid_pred)] 
    y_valid_pred_proba = model.predict_proba(X_valid)
    y_valid_pred_force_one, y_valid_pred_label_force_one = force_one_label(valid_set, y_valid_pred, y_valid_pred_proba)
    eval_result = pd.DataFrame(classification_report(y_valid_label, y_valid_pred_label_force_one, zero_division=0., labels=labels, output_dict=True)).T
    eval_result = eval_result.reset_index().rename(columns=dict(index="label"))
    eval_results.append(eval_result) 
    y_test_pred = model.predict(X_test)
    y_test_pred_proba = model.predict_proba(X_test)
    y_test_pred_label = ["nil" if p == 0 else y_test_label_pred[idx]  for idx, p in enumerate(y_test_pred)]
    y_test_pred_force_one, y_test_pred_label_force_one = force_one_label(test_set, y_test_pred, y_test_pred_proba)
eval_results = pd.concat(eval_results)
eval_results = eval_results.groupby("label").describe()
# Out:
# CPU times: total: 30.9 s
# Wall time: 31.6 s

# %% [markdown]
# # Evaluate
# ## Validation Set (5 runs)

# %%
show = [
    ("precision", "mean"),
    ("precision", "std"),
    ("recall", "mean"),
    ("recall", "std"),
    ("f1-score", "mean"),
    ("f1-score", "std"),
    ("support", "mean"),
]
eval_results[show]
# Out:
#                    precision                  recall            f1-score  \
#                         mean           std      mean       std      mean
# label
# Abbreviation_of     1.000000  0.000000e+00  1.000000  0.000000  1.000000
# AlternativeName_of  1.000000  0.000000e+00  1.000000  0.000000  1.000000
# Citation_of         0.933333  0.000000e+00  0.913043  0.000000  0.923077
# Developer_of        0.964706  1.241267e-16  0.942529  0.000000  0.953488
# Extension_of        1.000000  0.000000e+00  1.000000  0.000000  1.000000
# License_of          0.900000  0.000000e+00  0.900000  0.000000  0.900000
# PlugIn_of           0.831378  1.491982e-02  0.950000  0.019562  0.886654
# Release_of          1.000000  0.000000e+00  1.000000  0.000000  1.000000
# Specification_of    1.000000  0.000000e+00  0.488889  0.024845  0.656410
# URL_of              0.918033  1.159191e-02  0.918033  0.011592  0.918033
# Version_of          0.991093  3.387288e-03  0.991093  0.003387  0.991093
# macro avg           0.958049  8.074373e-04  0.918508  0.001813  0.929887
# micro avg           0.961023  1.368375e-03  0.944910  0.001640  0.952898
# weighted avg        0.962282  1.479255e-03  0.944910  0.001640  0.951006
#
#                                  support
#                              std    mean
# label
# Abbreviation_of     0.000000e+00     6.0
# AlternativeName_of  0.000000e+00     3.0
# Citation_of         0.000000e+00    92.0
# Developer_of        1.241267e-16   174.0
# Extension_of        0.000000e+00    13.0
# License_of          0.000000e+00    10.0
# PlugIn_of           1.401586e-02    28.0
# Release_of          0.000000e+00    16.0
# Specification_of    2.293403e-02    18.0
# URL_of              1.159191e-02    61.0
# Version_of          3.387288e-03   247.0
# macro avg           2.074251e-03   668.0
# micro avg           1.478771e-03   668.0
# weighted avg        1.412049e-03   668.0

# %% [markdown]
# ## Test Set

# %%
pd.DataFrame(classification_report(y_test_label, y_test_pred_label_force_one, zero_division=0., labels=labels, output_dict=True)).T
# Out:
#                     precision    recall  f1-score  support
# Version_of           0.981651  0.981651  0.981651    109.0
# Developer_of         0.939759  0.939759  0.939759     83.0
# Citation_of          0.977778  0.977778  0.977778     45.0
# URL_of               0.897436  0.897436  0.897436     39.0
# PlugIn_of            0.705882  0.923077  0.800000     13.0
# Specification_of     1.000000  0.375000  0.545455      8.0
# Release_of           1.000000  1.000000  1.000000      7.0
# Extension_of         1.000000  0.909091  0.952381     11.0
# License_of           0.727273  0.888889  0.800000      9.0
# Abbreviation_of      1.000000  1.000000  1.000000      5.0
# AlternativeName_of   1.000000  1.000000  1.000000      1.0
# micro avg            0.939394  0.939394  0.939394    330.0
# macro avg            0.929980  0.899335  0.899496    330.0
# weighted avg         0.944612  0.939394  0.937696    330.0

# %% [markdown]
# ### Best performance: 0.927

# %% [markdown]
# ## Look into wrong predictions (on test set)

# %%
ha = valid_set.copy()
ha["pred"] = y_valid_pred_label
cols = ["sentence", "subject_text", "target_label_binary", "object_text", "relation", "pred"]
ha = ha[list(y_valid_label != y_valid_pred_label_force_one)][cols]#.sample(3)
len(ha)
# Out:
# 61

# %%
ha.target_label_binary.value_counts()
# Out:
# target_label_binary
# Developer_of        16
# Citation_of         14
# Specification_of    10
# URL_of              10
# PlugIn_of            7
# License_of           2
# Name: count, dtype: int64

# %%
#pd.Series(y_test).value_counts(), pd.Series(y_test_pred).value_counts(), y_test_pred_force_one.value_counts()

# %%
ha
# Out:
#                                                                                                                                                                                                                                                                                                          sentence  \
# 9                                                                                                                                                                                PyPhi is open - source and licensed under the GPLv 3 ; the source code is hosted on GitHub at https://github.com/wmayner/pyphi .
# 16                                                                                                                                                                                                             CoXpress is written in the native R language and has been fully tested on both windows and linux .
# 30    Mindboggle is a freely downloadable , open source software package written in Matlab ( version 6 , release 13 , with the Image Processing Toolbox , The Mathworks Inc . , USA ) and has been tested on different models of desktop and laptop computers running different distributions of Linux , as we...
# 39    Mindboggle is a freely downloadable , open source software package written in Matlab ( version 6 , release 13 , with the Image Processing Toolbox , The Mathworks Inc . , USA ) and has been tested on different models of desktop and laptop computers running different distributions of Linux , as we...
# 54                                                                                                                                                                                                                                  Availability : FunciSNP is available from Bioconductor ( bioconductor.org ) .
# 94    More details : Software name : CBFA plugin for Optflux Project home page : http://www.optflux.org/ Methods details and application tutorial : http://www.optflux.org/cbfa Operating system ( s ) : Platform independent Programming languages : Java Other requirements : Java JRE 1.7 .x ( for Mac OS u...
# 96    More details : Software name : CBFA plugin for Optflux Project home page : http://www.optflux.org/ Methods details and application tutorial : http://www.optflux.org/cbfa Operating system ( s ) : Platform independent Programming languages : Java Other requirements : Java JRE 1.7 .x ( for Mac OS u...
# 106   More details : Software name : CBFA plugin for Optflux Project home page : http://www.optflux.org/ Methods details and application tutorial : http://www.optflux.org/cbfa Operating system ( s ) : Platform independent Programming languages : Java Other requirements : Java JRE 1.7 .x ( for Mac OS u...
# 157   " • Project name : SSPACE - LongRead • Project home page : http://www.baseclear.com/bioinformatics-tools/ • Operating systems : All major Linux platforms • Programming languages : Perl , C + + ( the latter is required for BLASR , see below ) • Other requirements : BLASR for the alignment of long...
# 172   " • Project name : SSPACE - LongRead • Project home page : http://www.baseclear.com/bioinformatics-tools/ • Operating systems : All major Linux platforms • Programming languages : Perl , C + + ( the latter is required for BLASR , see below ) • Other requirements : BLASR for the alignment of long...
# 187                                                                       Here , we present a novel Python - based toolbox called HDDM ( hierarchical drift diffusion model ) , which allows fast and flexible estimation of the the drift - diffusion model and the related linear ballistic accumulator model .
# 351                                                                                        Expression Analysis of mRNAs and miRNAs : Statistical analyses to compare mRNA and miRNA expression profiles were performed using the " R " statistical environment edgeR [96] , vegan [97] and gplots [98] packages .
# 428                                                   All data processing and statistical analyses were performed with the Statistical Package for Social Science ( SPSS ) software , vers . 18.0 ( SPSS , Chicago , IL , USA ) and SAS vers . 8.2 ( SAS System for Windows , SAS Institute , Cary , NC , USA ) .
# 442                                                   All data processing and statistical analyses were performed with the Statistical Package for Social Science ( SPSS ) software , vers . 18.0 ( SPSS , Chicago , IL , USA ) and SAS vers . 8.2 ( SAS System for Windows , SAS Institute , Cary , NC , USA ) .
# 447                                                   All data processing and statistical analyses were performed with the Statistical Package for Social Science ( SPSS ) software , vers . 18.0 ( SPSS , Chicago , IL , USA ) and SAS vers . 8.2 ( SAS System for Windows , SAS Institute , Cary , NC , USA ) .
# 473                                                                                                                                                                 SMI software ( Experiment Center ™ and iView X ™ ) were used to collect and record calibration , present the stimuli , and record gaze data .
# 523                                                                                                                                                                                   The vocalization synthesis relied on the articulatory synthesizer developed by Boersma and available in Praat [ 61 , 66 ] .
# 578                               As a measure of the test - retest reliability of the degree of lateralization , we computed an ICC ( two - way mixed model with absolute agreement using SPSS ; IBM SPSS Statistics for Macintosh , version 22.0 ) for the LIs in the frontal and parietal ROI , respectively .
# 614                                                                                                                                                                                                                                                                      Figure generated using clam for R [53] .
# 615                                                                                                                                                                                                                                                                      Figure generated using clam for R [53] .
# 617                                                                                 Cluster analysis was used to determine boundaries between diatom assemblage zones in the stratigraphy , with the number of significant zones evaluated by the broken stick model , using the rioja package in R [ 62 , 63 ] .
# 624                                             To calculate the ARI scores , we used the function “ adjustedRandIndex ” in R software [58] , [59] and , for the ICC and AIC , we use the R function “ lmer ” [60] that employs a Restricted Maximum Likelihood procedure [61] to obtain estimates of , and AIC .
# 625                                             To calculate the ARI scores , we used the function “ adjustedRandIndex ” in R software [58] , [59] and , for the ICC and AIC , we use the R function “ lmer ” [60] that employs a Restricted Maximum Likelihood procedure [61] to obtain estimates of , and AIC .
# 630                                             To calculate the ARI scores , we used the function “ adjustedRandIndex ” in R software [58] , [59] and , for the ICC and AIC , we use the R function “ lmer ” [60] that employs a Restricted Maximum Likelihood procedure [61] to obtain estimates of , and AIC .
# 631                                             To calculate the ARI scores , we used the function “ adjustedRandIndex ” in R software [58] , [59] and , for the ICC and AIC , we use the R function “ lmer ” [60] that employs a Restricted Maximum Likelihood procedure [61] to obtain estimates of , and AIC .
# 671                                                                                                  All statistical tests , carried out in R Studio Version 0.98.1102 and SPSS ( IBM SPSS Statistics for Macintosh , version 22.0 ) , were two - tailed and the statistical significance level was set at 0.05 .
# 719             The software used for spectrum visualization and MS / MSMS protein identification was Flex Analysis ( v. 3.3 ) and BioTools ( Bruker Daltonics ) linked to MASCOT ( Matrix Science , Boston , MA 2016 ( http://www.matrixscience.com/ ) to search against the NCBInr protein sequence databases .
# 720             The software used for spectrum visualization and MS / MSMS protein identification was Flex Analysis ( v. 3.3 ) and BioTools ( Bruker Daltonics ) linked to MASCOT ( Matrix Science , Boston , MA 2016 ( http://www.matrixscience.com/ ) to search against the NCBInr protein sequence databases .
# 723                                                                                                                                   All statistical analysis was performed using R ver. 2.15.1 ( R Development Core Team ; www.r-project.org ) with critical P - values set to 0.05 , unless otherwise stated .
# 724                                                                                                                                   All statistical analysis was performed using R ver. 2.15.1 ( R Development Core Team ; www.r-project.org ) with critical P - values set to 0.05 , unless otherwise stated .
# 730                                    To extract noun phrases to use as search terms for each of the papers on PubMed Central , we run a software program written in Python based NLTK ( http://www.nltk.org/ ) to automatically extract nouns , adjectives , and noun phrases from each sentence in the paper .
# 731                                    To extract noun phrases to use as search terms for each of the papers on PubMed Central , we run a software program written in Python based NLTK ( http://www.nltk.org/ ) to automatically extract nouns , adjectives , and noun phrases from each sentence in the paper .
# 861                                                                                                                                                  Then , the hypotheses were tested with OLS Ordinary Least Square through the PROCESS macro for SPSS , which assesses the conditional indirect effects [38] .
# 862                                                                                                                                                  Then , the hypotheses were tested with OLS Ordinary Least Square through the PROCESS macro for SPSS , which assesses the conditional indirect effects [38] .
# 867                                                                                                                                 Analysis was then done by one researcher ( SS ) using MSOffice ( Word and Excel , Microsoft Corp . ) and NVivo ( QSR International ) software for qualitative data analysis .
# 873                                                                                                                                 Analysis was then done by one researcher ( SS ) using MSOffice ( Word and Excel , Microsoft Corp . ) and NVivo ( QSR International ) software for qualitative data analysis .
# 877                                                                                                                                 Analysis was then done by one researcher ( SS ) using MSOffice ( Word and Excel , Microsoft Corp . ) and NVivo ( QSR International ) software for qualitative data analysis .
# 881                                                                                                                                 Analysis was then done by one researcher ( SS ) using MSOffice ( Word and Excel , Microsoft Corp . ) and NVivo ( QSR International ) software for qualitative data analysis .
# 955                                                                                                                                                                                                   The data were analyzed using SPSS software ( Statistical Package for the Social Sciences , version 17.0 ) .
# 976                                                                                                                                                                                                All three stages of analysis were conducted using SPSS software ( IBM SPSS Statistics 20 , IBM Corporation ) .
# 1069                                                                                           The images were subsequently processed and analyzed on a pixel - by - pixel basis using the Matlab Image Processing Toolbox ( Mathworks , Matlab v 2011b ) using script modified from Theyel and colleagues [20] .
# 1071                                                                                           The images were subsequently processed and analyzed on a pixel - by - pixel basis using the Matlab Image Processing Toolbox ( Mathworks , Matlab v 2011b ) using script modified from Theyel and colleagues [20] .
# 1073                                                                                           The images were subsequently processed and analyzed on a pixel - by - pixel basis using the Matlab Image Processing Toolbox ( Mathworks , Matlab v 2011b ) using script modified from Theyel and colleagues [20] .
# 1076                                                                                           The images were subsequently processed and analyzed on a pixel - by - pixel basis using the Matlab Image Processing Toolbox ( Mathworks , Matlab v 2011b ) using script modified from Theyel and colleagues [20] .
# 1139                                                                                                                              Statistical analyses were conducted using Statistical Package for the Social Sciences Version 20.0 ( SPSS 20.0 ) and Analysis of Moment Structures Version 20.0 ( AMOS 20.0 ) .
# 1154                For the pre - processing and statistical analyses , the statistical parametric mapping software package ( SPM 5 , Wellcome Department of Cognitive Neurology , London ; www.fil.ion.ucl.ac.uk/spm ) was used and implemented in Matlab ( Mathworks , Inc . , Natick , MA , USA release 14 ) .
# 1174                All analyses were performed using SAS / STAT ™ software version 9.1 ( SAS Institute Inc . , Cary , NC ) , Statistical Package for the Social Sciences ™ for Windows ™ ( SPSS ™ version 14.1 , SPSS Inc . , Chicago , IL ) , and RevMan version 4.1 ( Cochrane Collaboration , Oxford , UK ) .
# 1193                All analyses were performed using SAS / STAT ™ software version 9.1 ( SAS Institute Inc . , Cary , NC ) , Statistical Package for the Social Sciences ™ for Windows ™ ( SPSS ™ version 14.1 , SPSS Inc . , Chicago , IL ) , and RevMan version 4.1 ( Cochrane Collaboration , Oxford , UK ) .
# 1228                                                                                                                           DLMs were implemented using the dlnm package version 2.2.6 in R Studio ( Vienna , Austria ) and other analyses were performed in SAS ( v 9.4 , SAS Institute Inc . , Cary , NC ) .
# 1345                                                                                          The IVDDM and IVDGE of feedstuffs were compared using the MIXED procedure of SAS ( SAS v 9.2 , SAS Institute Inc . , Cary , NC , USA ) , where feedstuffs were treated as fixed factor and batch as random factor .
# 1351  We generated multilevel logistic regression models with random intercepts to evaluate the impact of patients and trust factors on each dependent variable using MLWin V. 2.31 software ( Rasbash J , Charlton C , Browne W , et al . MLwiN , Version 2.31 . Centre for Multilevel Modelling , University...
# 1353  We generated multilevel logistic regression models with random intercepts to evaluate the impact of patients and trust factors on each dependent variable using MLWin V. 2.31 software ( Rasbash J , Charlton C , Browne W , et al . MLwiN , Version 2.31 . Centre for Multilevel Modelling , University...
# 1357  We generated multilevel logistic regression models with random intercepts to evaluate the impact of patients and trust factors on each dependent variable using MLWin V. 2.31 software ( Rasbash J , Charlton C , Browne W , et al . MLwiN , Version 2.31 . Centre for Multilevel Modelling , University...
# 1399                                                                                                                                                           CIBERSORT analyses were performed on RNAseq data by using the analytical tool developed by Newman et al . ( http://cibersort.stanford.edu ) [30] .
# 1401                                                                                                                                                           CIBERSORT analyses were performed on RNAseq data by using the analytical tool developed by Newman et al . ( http://cibersort.stanford.edu ) [30] .
# 1421                                                                                                                                                                                                                                           Data were imported and normalized using the ChAMP R package [59] .
# 1422                                                                                                                                                                                                                                           Data were imported and normalized using the ChAMP R package [59] .
# 1438                                                                                                                                                                                     Differential expression genes between the infected and control groups were identified with the DESeq of R package [13] .
# 1439                                                                                                                                                                                     Differential expression genes between the infected and control groups were identified with the DESeq of R package [13] .
#
#                                      subject_text target_label_binary  \
# 9                                           PyPhi           PlugIn_of
# 16                                       CoXpress           PlugIn_of
# 30                            The Mathworks Inc .        Developer_of
# 39                            The Mathworks Inc .        Developer_of
# 54                                   Bioconductor           PlugIn_of
# 94                                           CBFA           PlugIn_of
# 96                    http://www.optflux.org/cbfa              URL_of
# 106                   http://www.optflux.org/cbfa              URL_of
# 157                                     BaseTools          License_of
# 172                                     BaseTools          License_of
# 187                                          HDDM           PlugIn_of
# 351                                        gplots           PlugIn_of
# 428                                          SPSS        Developer_of
# 442                                          SPSS        Developer_of
# 447                                           SAS    Specification_of
# 473                                           SMI        Developer_of
# 523                                   [ 61 , 66 ]         Citation_of
# 578                               SPSS Statistics    Specification_of
# 614                                          [53]         Citation_of
# 615                                          [53]         Citation_of
# 617                                   [ 62 , 63 ]         Citation_of
# 624                                          [58]         Citation_of
# 625                                          [59]         Citation_of
# 630                                          [58]         Citation_of
# 631                                          [59]         Citation_of
# 671                               SPSS Statistics    Specification_of
# 719                 http://www.matrixscience.com/              URL_of
# 720                 http://www.matrixscience.com/              URL_of
# 723                             www.r-project.org              URL_of
# 724                             www.r-project.org              URL_of
# 730                          http://www.nltk.org/              URL_of
# 731                          http://www.nltk.org/              URL_of
# 861                                          [38]         Citation_of
# 862                                          [38]         Citation_of
# 867                              Microsoft Corp .        Developer_of
# 873                              Microsoft Corp .        Developer_of
# 877                              Microsoft Corp .        Developer_of
# 881                              Microsoft Corp .        Developer_of
# 955   Statistical Package for the Social Sciences    Specification_of
# 976                               SPSS Statistics    Specification_of
# 1069                                    Mathworks        Developer_of
# 1071                                       Matlab    Specification_of
# 1073                                    Mathworks        Developer_of
# 1076                                    Mathworks        Developer_of
# 1139                                         AMOS    Specification_of
# 1154                                          SPM    Specification_of
# 1174                          SAS Institute Inc .        Developer_of
# 1193                          SAS Institute Inc .        Developer_of
# 1228                                         dlnm           PlugIn_of
# 1345                                          SAS    Specification_of
# 1351  Rasbash J , Charlton C , Browne W , et al .        Developer_of
# 1353                                        MLwiN    Specification_of
# 1357  Rasbash J , Charlton C , Browne W , et al .        Developer_of
# 1399                http://cibersort.stanford.edu              URL_of
# 1401                http://cibersort.stanford.edu              URL_of
# 1421                                         [59]         Citation_of
# 1422                                         [59]         Citation_of
# 1438                                         [13]         Citation_of
# 1439                                         [13]         Citation_of
#
#                                       object_text          relation  \
# 9                                          GitHub               nil
# 16                                              R               nil
# 30                                         Matlab      Developer_of
# 39                       Image Processing Toolbox               nil
# 54                                       FunciSNP               nil
# 94                                        Optflux               nil
# 96                                           CBFA            URL_of
# 106                                       Optflux               nil
# 157                             SSPACE - LongRead        License_of
# 172                                         BLASR               nil
# 187                                        Python               nil
# 351                                             R         PlugIn_of
# 428        Statistical Package for Social Science      Developer_of
# 442                                           SAS               nil
# 447                                           SAS  Specification_of
# 473                                       iView X      Developer_of
# 523                      articulatory synthesizer       Citation_of
# 578                                          SPSS  Specification_of
# 614                                          clam       Citation_of
# 615                                             R               nil
# 617                                         rioja       Citation_of
# 624                             adjustedRandIndex       Citation_of
# 625                             adjustedRandIndex       Citation_of
# 630                                             R               nil
# 631                                             R               nil
# 671                                          SPSS  Specification_of
# 719                                        MASCOT            URL_of
# 720                                Matrix Science               nil
# 723                                             R            URL_of
# 724                       R Development Core Team               nil
# 730                                        Python            URL_of
# 731                                          NLTK               nil
# 861                                       PROCESS       Citation_of
# 862                                          SPSS               nil
# 867                                      MSOffice      Developer_of
# 873                                          Word      Developer_of
# 877                                         Excel      Developer_of
# 881                                         NVivo               nil
# 955                                          SPSS  Specification_of
# 976                                          SPSS  Specification_of
# 1069                                       Matlab      Developer_of
# 1071                                       Matlab  Specification_of
# 1073                     Image Processing Toolbox      Developer_of
# 1076                                       Matlab               nil
# 1139                Analysis of Moment Structures  Specification_of
# 1154               statistical parametric mapping  Specification_of
# 1174                                          SAS      Developer_of
# 1193  Statistical Package for the Social Sciences               nil
# 1228                                     R Studio               nil
# 1345                                          SAS  Specification_of
# 1351                                        MLWin      Developer_of
# 1353                                        MLWin  Specification_of
# 1357                                        MLwiN               nil
# 1399                                    CIBERSORT            URL_of
# 1401                               Newman et al .               nil
# 1421                                        ChAMP       Citation_of
# 1422                                            R               nil
# 1438                                        DESeq       Citation_of
# 1439                                            R               nil
#
#               pred
# 9        PlugIn_of
# 16       PlugIn_of
# 30             nil
# 39    Developer_of
# 54       PlugIn_of
# 94       PlugIn_of
# 96             nil
# 106            nil
# 157            nil
# 172            nil
# 187      PlugIn_of
# 351            nil
# 428            nil
# 442            nil
# 447            nil
# 473            nil
# 523            nil
# 578            nil
# 614            nil
# 615    Citation_of
# 617            nil
# 624            nil
# 625            nil
# 630    Citation_of
# 631    Citation_of
# 671            nil
# 719            nil
# 720         URL_of
# 723            nil
# 724         URL_of
# 730            nil
# 731         URL_of
# 861            nil
# 862    Citation_of
# 867            nil
# 873            nil
# 877            nil
# 881   Developer_of
# 955            nil
# 976            nil
# 1069           nil
# 1071           nil
# 1073           nil
# 1076  Developer_of
# 1139           nil
# 1154           nil
# 1174           nil
# 1193  Developer_of
# 1228     PlugIn_of
# 1345           nil
# 1351           nil
# 1353           nil
# 1357  Developer_of
# 1399           nil
# 1401           nil
# 1421           nil
# 1422   Citation_of
# 1438           nil
# 1439   Citation_of
